# %%
import tensorflow as tf
import numpy as np

# %%
# Step 1 : Converting data to numPy arrays
x = np.array([1, 2, 3, 4], dtype = float)
y = np.array([2, 4, 6, 8], dtype = float)

# %%
# Step 2 : Define model using Input layer (recommended)
model = tf.keras.Sequential([
    tf.keras.Input(shape = (1,)),
    tf.keras.layers.Dense(1)
])

# %%
# Step 3 : Comppile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Step 4 : Training the model
model.fit(x, y, epochs = 10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4907
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.0658
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.7708
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5658
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.4235
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3245
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.2556
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2077
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.1742
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1508

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
model=nn.Linear(1,1)
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)
x= torch.tensor([[1.],[2.],[3.],[4.]])
y= torch.tensor([[2.],[4.],[6.],[8.]])

for epoch in range(10):
    optimizer.zero_grad()
    outputs=model(x)
    loss=criterion(outputs,y)
    loss.backward()
    optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item()}')
# Out:
# Epoch 1, Loss: 24.923595428466797
# Epoch 2, Loss: 17.294191360473633
# Epoch 3, Loss: 12.000310897827148
# Epoch 4, Loss: 8.326996803283691
# Epoch 5, Loss: 5.778161525726318
# Epoch 6, Loss: 4.009576797485352
# Epoch 7, Loss: 2.7823922634124756
# Epoch 8, Loss: 1.9308738708496094
# Epoch 9, Loss: 1.3400206565856934
# Epoch 10, Loss: 0.9300403594970703

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# Step 1: data
x = np.array([1, 2, 3, 4], dtype=float)
y = np.array([2, 4, 6, 8], dtype=float)

# Step 2: define model (FIXED)
model = Sequential([
    Input(shape=(1,)),
    Dense(1)
])

# Step 3: compile
model.compile(
    optimizer='sgd',
    loss='mean_squared_error'
)

# Step 4: train
model.fit(x, y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 65.3889
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 45.4126
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 31.5512
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 21.9329
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 15.2586
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - loss: 10.6273
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 7.4135
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 5.1832
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 3.6355
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 2.5613
